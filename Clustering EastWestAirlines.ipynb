# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN, KMeans, AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import scipy.cluster.hierarchy as sch
df = pd.read_excel("C:\\Users\\User\\Downloads\\EastWestAirlines.xlsx",sheet_name="data")

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df)

# %%
X
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
# DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(X)

# %%
#Kmeans
kmeans = KMeans(n_clusters=10, random_state=42)
kmeans_labels = kmeans.fit_predict(X)

# %%
#Agglomerative
agglo = AgglomerativeClustering(n_clusters=10)
agglo_labels = agglo.fit_predict(X)

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 3, 1)
plt.scatter(X[:, 0], X[:, 1], c=dbscan_labels)
plt.title("DBSCAN")

plt.subplot(1, 3, 2)
plt.scatter(X[:, 0], X[:, 1], c=kmeans_labels)
plt.title("KMeans")

plt.subplot(1, 3, 3)
plt.scatter(X[:, 0], X[:, 1], c=agglo_labels)
plt.title("Agglomerative")

plt.show()

# %% [markdown]
# # Dendrogram

# %%
plt.figure(figsize=(11,7))

plt.subplot(221)
dendrogram = sch.dendrogram(sch.linkage(X,method="single"))
plt.title("Single")

plt.subplot(222)
dendrogram = sch.dendrogram(sch.linkage(X,method="ward"))
plt.title("Ward")

plt.subplot(223)
dendrogram = sch.dendrogram(sch.linkage(X,method="average"))
plt.title("Average")

plt.subplot(224)
dendrogram = sch.dendrogram(sch.linkage(X,method="complete"))
plt.title("Complete")

plt.show()

# %% [markdown]
# # Perform agglomerative clustering using Euclidean distance

# %%
single= AgglomerativeClustering(n_clusters= 10 ,affinity = "euclidean", linkage="single")
single= single_e.fit_predict(X)
ward = AgglomerativeClustering(n_clusters= 10 ,affinity = "euclidean", linkage="ward")
ward= ward.fit_predict(X)
complete = AgglomerativeClustering(n_clusters= 10 ,affinity = "euclidean", linkage="complete")
complete=complete.fit_predict(X)
Average= AgglomerativeClustering(n_clusters= 10 ,affinity = "euclidean", linkage="average")
average= Average.fit_predict(X)

# %%
Euclidean_d= pd.DataFrame(list(zip(single_l,ward,complete,average)), columns=["Single","Ward","Complete","Average"])

# %%
Euclidean_d
# Out:
#       Single  Ward  Complete  Average
# 0          1     6         2        2
# 1          1     6         2        2
# 2          1     6         2        2
# 3          1     6         2        2
# 4          1     4         2        2
# ...      ...   ...       ...      ...
# 3994       1     2         2        2
# 3995       1     2         2        2
# 3996       1     2         2        2
# 3997       1     3         2        2
# 3998       1     3         2        2
#
# [3999 rows x 4 columns]

# %%
plt.figure(figsize=(11,7))

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1],c=single)
plt.title("single")

plt.subplot(222)
plt.scatter(X[:, 0], X[:, 1], c=ward)
plt.title("ward")

plt.subplot(223)
plt.scatter(X[:, 0], X[:, 1], c=complete)
plt.title("complete")

plt.subplot(224)
plt.scatter(X[:, 0], X[:, 1], c=average)
plt.title("average")

plt.show()

# %% [markdown]
# # Perform agglomerative clustering using cosine similarity

# %%
cosine_s= AgglomerativeClustering(n_clusters= 10 ,affinity = "cosine", linkage="single")
single_c= cosine_s.fit_predict(X)
cosine_c= AgglomerativeClustering(n_clusters= 10 ,affinity = "cosine", linkage="complete")
complete_c=cosine_c.fit_predict(X)
cosine_a= AgglomerativeClustering(n_clusters= 10 ,affinity = "cosine", linkage="average")
average_c= cosine_a.fit_predict(X)

# %%
cosine= pd.DataFrame(list(zip(single_c,complete_c,average_c)), columns=["Single","Complete","Average"])

# %%
cosine
# Out:
#       Single  Complete  Average
# 0          0         8        0
# 1          0         8        0
# 2          0         8        0
# 3          0         8        0
# 4          0         0        1
# ...      ...       ...      ...
# 3994       0         6        3
# 3995       0         6        3
# 3996       0         0        1
# 3997       0         3        0
# 3998       0         3        0
#
# [3999 rows x 3 columns]

# %%
plt.figure(figsize=(11,7))

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1],c=single_c)
plt.title("single")

plt.subplot(222)
plt.scatter(X[:, 0], X[:, 1], c=complete_c)
plt.title("complete")

plt.subplot(223)
plt.scatter(X[:, 0], X[:, 1], c=average_c)
plt.title("average")

plt.show()

# %% [markdown]
# # Perform agglomerative clustering using manhattan distance

# %%
m_s = AgglomerativeClustering(n_clusters= 10 ,affinity = "manhattan", linkage="single")
single_m= m_s.fit_predict(X)
m_c= AgglomerativeClustering(n_clusters= 10 ,affinity = "manhattan", linkage="complete")
complete_m=m_c.fit_predict(X)
m_a= AgglomerativeClustering(n_clusters= 10 ,affinity = "manhattan", linkage="average")
average_m= m_a.fit_predict(X)

# %%
manhattan = pd.DataFrame(list(zip(single_m,complete_m,average_m)), columns=["Single","Complete","Average"])

# %%
manhattan
# Out:
#       Single  Complete  Average
# 0          1         8        4
# 1          1         8        4
# 2          1         8        4
# 3          1         8        4
# 4          1         5        4
# ...      ...       ...      ...
# 3994       1         5        4
# 3995       1         5        4
# 3996       1         5        4
# 3997       1         5        4
# 3998       1         5        4
#
# [3999 rows x 3 columns]

# %%
plt.figure(figsize=(11,7))

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1],c=single_m)
plt.title("single")

plt.subplot(222)
plt.scatter(X[:, 0], X[:, 1], c=complete_m)
plt.title("complete")

plt.subplot(223)
plt.scatter(X[:, 0], X[:, 1], c=average_m)
plt.title("average")

plt.show()
